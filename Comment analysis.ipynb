# %% [markdown]
# <a href="https://colab.research.google.com/github/kattaGowthami/comment-analysis/blob/main/Comment%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Packages**

# %%
import pandas as pd; import os
import csv; import numpy as np
import re; import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Reading Pre-Labeled YouTube Video Comments**

# %% [markdown]
# Here we are taking pre-labeled comments of 5 popular youtube videos for training & testing

# %%
okgo = pd.read_csv('/content/OKGO.csv', delimiter=";", skiprows=2, encoding='latin-1', engine='python') # read in the data
trump = pd.read_csv('/content/trump.csv', delimiter=",", skiprows=2, encoding='utf-8', error_bad_lines=False, engine='python')
swift = pd.read_csv('/content/TaylorSwift.csv', delimiter=",", skiprows=2, nrows=180, encoding='utf-8', engine='python')
royal = pd.read_csv('/content/RoyalWedding.csv', delimiter=",", skiprows=2, nrows=61, encoding='utf-8', engine='python')
paul = pd.read_csv('/content/LoganPaul.csv', delimiter=",", skiprows=2, nrows=200, encoding='utf-8', engine='python')

# %%
okgo
# Out:
#         1  \
# 0    -1.0
# 1     0.0
# 2     1.0
# 3     1.0
# 4     0.0
# ...   ...
# 4343  NaN
# 4344  NaN
# 4345  NaN
# 4346  NaN
# 4347  NaN
#
#      Ive been waiting for this music video ever since the song came out on Hungry Ghosts  \
# 0     Everyone knows brand's papers from.\rBut -No o...
# 1          ÒYour paper cut balance is: \r-£25279102771Ó
# 2     OH SHIT WHEN I SAW THIS ON MY FRONT PAGE.........
# 3                             Blowing my mind yet again
# 4                  Should have gone with Dunder Mifflin
# ...                                                 ...
# 4343                               Two days 17 views?!!
# 4344                          wow took you this long :)
# 4345              Love the video tho good work everyone
# 4346                                                NaN
# 4347                                                NaN
#
#       Unnamed: 2  Unnamed: 3
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 4343         NaN         NaN
# 4344         NaN         NaN
# 4345         NaN         NaN
# 4346         NaN         NaN
# 4347         NaN         NaN
#
# [4348 rows x 4 columns]

# %%
trump
# Out:
#       1                                 Hispanic for Trump!
# 0     -1  Taking down this video for copyright infringem...
# 1     -1  This speech literaly ripped off the Dark Knigh...
# 2     -1                                           Poop him
# 3     -1             He's speeching like a communist leader
# 4      0  Play this with https://www.youtube.com/watch?v...
# ..   ...                                                ...
# 194    1  People still haven't understood the meaning of...
# 195   -1    To quote George W. Bush: Thats some weird shit.
# 196    1  I was there 1 year ago today. The greatest exp...
# 197    1                        Wish I could of been there.
# 198    0  https://trumpgasm.wordpress.com/2015/12/15/glo...
#
# [199 rows x 2 columns]

# %%
swift
# Out:
#        1                                     Best song ever
# 0    1.0                                            Love it
# 1    0.0                  Buraya trk gelmemi dediler geldik
# 2    1.0          I love this music and Taylor Swift 3great
# 3    1.0                                        Ay love you
# 4    1.0                      Im a huge fan of Taylor swift
# ..   ...                                                ...
# 175  1.0                      i sing this so well i love it
# 176  0.0  Some people say that old taylors dead but its ...
# 177  0.0                         I knew you were meme maker
# 178  NaN                         Me recuerda a Patch y nora
# 179  NaN                                         Hello john
#
# [180 rows x 2 columns]

# %%
royal
# Out:
#     0  \
# 0   1
# 1   0
# 2   0
# 3   1
# 4   0
# .. ..
# 56  1
# 57  1
# 58  1
# 59  1
# 60  0
#
#    British prince marries a woman who is only partly African in 2018 and everybody claims it a pinnacle of tolerance Russian tsar and first emperor Peter I makes Abram Gannibal the first African to come to Russia a pure Black person lad his godson and an aristocrat giving him a nobility in 1705 century later his grandson Alexander Pushkin becomes the most admired Russian poet and writer what should that be called then
# 0                       Ooo Stand By Me nice addition
# 1   Az regasszonymeg a csvmintha nyugdijas klubba ...
# 2   Fast forward top the 730 point unless you like...
# 3                      the first 4 hours were amazing
# 4                                Demetria Gene Guynes
# ..                                                ...
# 56  this marriage vows i love old fashioned and be...
# 57                            love this marriage vows
# 58  my favourite songwow choirso happy they chose ...
# 59  that is awesome preachingcongrationals prince ...
# 60                 was that the sound of the vuvuzela
#
# [61 rows x 2 columns]

# %%
paul
# Out:
#      1  \
# 0   -1
# 1   -1
# 2   -1
# 3    0
# 4   -1
# ..  ..
# 195 -1
# 196 -1
# 197 -1
# 198 -1
# 199  0
#
#     wow i just heard about this guy. easily the most insecure douche i have ever seen on youtube. he clearly has some mental issues and needs to be evaluated. give this guy the help he needs asap!  \
# 0    How can he do this? Japanese are trying to be ...
# 1                                                Prick
# 2                     I think all the weeds are crying
# 3    Lmao Americans in the comment section are acti...
# 4                How many people want to kill him now?
# ..                                                 ...
# 195                        He makes Americans look bad
# 196                     OMG no stop Japan my fav STOPP
# 197             This guy is making the U.S look bad...
# 198  I thought Logan Paul was nicer than jake Paul ...
# 199                        Can he do it front Yakuza ?
#
#     Unnamed: 2
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 195        NaN
# 196        NaN
# 197        NaN
# 198        NaN
# 199        NaN
#
# [200 rows x 3 columns]

# %% [markdown]
# **Reading Pre-Labeled Tweets & Blog Comments**

# %%
blogs = pd.read_csv('/content/Kagel.csv', delimiter=",", skiprows=2, encoding='latin-1', engine='python') # read in the data
tweets = pd.read_csv('/content/twitter.csv', delimiter=",", skiprows=2, encoding='latin-1', engine='python') # read in the data

# %%
blogs
# Out:
#       1.0  \
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# ...   ...
# 7079  0.0
# 7080  0.0
# 7081  0.0
# 7082  0.0
# 7083  0.0
#
#       this was the first clive cussler i've ever read but even books like Relic and Da Vinci code were more plausible than this
# 0                       i liked the Da Vinci Code a lot
# 1                       i liked the Da Vinci Code a lot
# 2      I liked the Da Vinci Code but it ultimatly di...
# 3      that's not even an exaggeration ) and at midn...
# 4      I loved the Da Vinci Code but now I want some...
# ...                                                 ...
# 7079                      Brokeback Mountain was boring
# 7080        So Brokeback Mountain was really depressing
# 7081   As I sit here watching the MTV Movie Awards I...
# 7082     Ok brokeback mountain is such a horrible movie
# 7083     Oh and Brokeback Mountain was a terrible movie
#
# [7084 rows x 2 columns]

# %%
tweets
# Out:
#         Topic   Sentiment             TweetId                       TweetDate  \
# 0       apple    positive  126415614616154112  Tue Oct 18 21:53:25 +0000 2011
# 1       apple    positive  126404574230740992  Tue Oct 18 21:09:33 +0000 2011
# 2       apple    positive  126402758403305474  Tue Oct 18 21:02:20 +0000 2011
# 3       apple    positive  126397179614068736  Tue Oct 18 20:40:10 +0000 2011
# 4       apple    positive  126395626979196928  Tue Oct 18 20:34:00 +0000 2011
# ...       ...         ...                 ...                             ...
# 5108  twitter  irrelevant  126855687060987904  Thu Oct 20 03:02:07 +0000 2011
# 5109  twitter  irrelevant  126855171702661120  Thu Oct 20 03:00:04 +0000 2011
# 5110  twitter  irrelevant  126854999442587648  Thu Oct 20 02:59:23 +0000 2011
# 5111  twitter  irrelevant  126854818101858304  Thu Oct 20 02:58:40 +0000 2011
# 5112  twitter  irrelevant  126854423317188608  Thu Oct 20 02:57:06 +0000 2011
#
#                                               TweetText
# 0     Now all @Apple has to do is get swype on the i...
# 1     @Apple will be adding more carrier support to ...
# 2     Hilarious @youtube video - guy does a duet wit...
# 3     @RIM you made it too easy for me to switch to ...
# 4     I just realized that the reason I got into twi...
# ...                                                 ...
# 5108                           me re copÃ¨ con #twitter
# 5109  Buenas noches genteeee :) #twitter los quieroo...
# 5110  #twitter tiene la mala costumbre de ponerce bn...
# 5111  Oi @flaviasansi. Muito bem vinda ao meu #Twitt...
# 5112  Eles arrastaram os barcos para a praia, deixar...
#
# [5113 rows x 5 columns]

# %% [markdown]
# **Data Preprocessing**

# %%
tweets = tweets.drop(['Topic', 'TweetId', "TweetDate"], axis = 1).dropna()
tweets.head()
# Out:
#   Sentiment                                          TweetText
# 0  positive  Now all @Apple has to do is get swype on the i...
# 1  positive  @Apple will be adding more carrier support to ...
# 2  positive  Hilarious @youtube video - guy does a duet wit...
# 3  positive  @RIM you made it too easy for me to switch to ...
# 4  positive  I just realized that the reason I got into twi...

# %%
def fix_cols(DF):
    DF = DF.iloc[:,:2]
    DF.columns = ["label", "comment"]
    return DF

# %%
okgo = fix_cols(okgo)
trump = fix_cols(trump)
swift = fix_cols(swift)
royal = fix_cols(royal)
paul = fix_cols(paul)
tweets = fix_cols(tweets)

# %%
okgo.head()
# Out:
#    label                                            comment
# 0   -1.0  Everyone knows brand's papers from.\rBut -No o...
# 1    0.0       ÒYour paper cut balance is: \r-£25279102771Ó
# 2    1.0  OH SHIT WHEN I SAW THIS ON MY FRONT PAGE.........
# 3    1.0                          Blowing my mind yet again
# 4    0.0               Should have gone with Dunder Mifflin

# %%
tweets.label = tweets.label.replace({'positive': '1.0', 'negative':'-1.0', 'neutral': '0.0', 'irrelevant': '0.0'}, regex=True)
tweets['label'] = pd.to_numeric(tweets['label'], errors='coerce')

# %%
tweets = fix_cols(tweets)
blogs = fix_cols(blogs)

# %%
tweets.head()
# Out:
#    label                                            comment
# 0    1.0  Now all @Apple has to do is get swype on the i...
# 1    1.0  @Apple will be adding more carrier support to ...
# 2    1.0  Hilarious @youtube video - guy does a duet wit...
# 3    1.0  @RIM you made it too easy for me to switch to ...
# 4    1.0  I just realized that the reason I got into twi...

# %% [markdown]
# **Create Datasets**

# %%
yt_comments = pd.concat([okgo, trump, swift, royal, paul], ignore_index=True)
yt_comments.head()
# Out:
#    label                                            comment
# 0   -1.0  Everyone knows brand's papers from.\rBut -No o...
# 1    0.0       ÒYour paper cut balance is: \r-£25279102771Ó
# 2    1.0  OH SHIT WHEN I SAW THIS ON MY FRONT PAGE.........
# 3    1.0                          Blowing my mind yet again
# 4    0.0               Should have gone with Dunder Mifflin

# %%
non_yt_comments = pd.concat([blogs, tweets], ignore_index=True)
non_yt_comments.head()
# Out:
#    label                                            comment
# 0    1.0                    i liked the Da Vinci Code a lot
# 1    1.0                    i liked the Da Vinci Code a lot
# 2    1.0   I liked the Da Vinci Code but it ultimatly di...
# 3    1.0   that's not even an exaggeration ) and at midn...
# 4    1.0   I loved the Da Vinci Code but now I want some...

# %%
comments = pd.concat([yt_comments, non_yt_comments], ignore_index=True)
comments.head()
# Out:
#    label                                            comment
# 0   -1.0  Everyone knows brand's papers from.\rBut -No o...
# 1    0.0       ÒYour paper cut balance is: \r-£25279102771Ó
# 2    1.0  OH SHIT WHEN I SAW THIS ON MY FRONT PAGE.........
# 3    1.0                          Blowing my mind yet again
# 4    0.0               Should have gone with Dunder Mifflin

# %% [markdown]
# **Remove Non-Alphabetic Characters (including numbers)**

# %%
def convert_to_string(DF):
    DF["comment"]= DF["comment"].astype(str)

# %%
convert_to_string(comments)

# %%
def cleanerFn(b):
    # keeps only words with alphabetic characters in comments
    for row in range(len(b)):
        line = b.loc[row, "comment"]
        b.loc[row,"comment"] = re.sub("[^a-zA-Z]", " ", line)

# %%
cleanerFn(comments)

# %%
comments.head()
# Out:
#    label                                            comment
# 0   -1.0  Everyone knows brand s papers from  But  No on...
# 1    0.0         Your paper cut balance is
# 2    1.0  OH SHIT WHEN I SAW THIS ON MY FRONT PAGE      ...
# 3    1.0                          Blowing my mind yet again
# 4    0.0               Should have gone with Dunder Mifflin

# %% [markdown]
# **Natural Language Processing**

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
sw = stopwords.words('english')
ps = PorterStemmer()
lemmatizer = nltk.stem.WordNetLemmatizer()

# %% [markdown]
# **Tokenization, Remove Stop Words, Lemmatization & Stemming**

# %%
def nlpFunction(DF):
    DF['com_token'] = DF['comment'].str.lower().str.split()
    DF['com_remv'] = DF['com_token'].apply(lambda x: [y for y in x if y not in sw])
    DF["com_lemma"] = DF['com_remv'].apply(lambda x : [lemmatizer.lemmatize(y) for y in x]) # lemmatization
    DF['com_stem'] = DF['com_lemma'].apply(lambda x : [ps.stem(y) for y in x]) # stemming
    DF["com_tok_str"] = DF["com_stem"].apply(', '.join)
    DF["com_full"] = DF["com_remv"].apply(' '.join)
    return DF

# %%
comments = nlpFunction(comments)
comments.head()
# Out:
#    label                                            comment  \
# 0   -1.0  Everyone knows brand s papers from  But  No on...
# 1    0.0         Your paper cut balance is
# 2    1.0  OH SHIT WHEN I SAW THIS ON MY FRONT PAGE      ...
# 3    1.0                          Blowing my mind yet again
# 4    0.0               Should have gone with Dunder Mifflin
#
#                                            com_token  \
# 0  [everyone, knows, brand, s, papers, from, but,...
# 1                    [your, paper, cut, balance, is]
# 2  [oh, shit, when, i, saw, this, on, my, front, ...
# 3                    [blowing, my, mind, yet, again]
# 4        [should, have, gone, with, dunder, mifflin]
#
#                                             com_remv  \
# 0  [everyone, knows, brand, papers, one, knows, w...
# 1                              [paper, cut, balance]
# 2           [oh, shit, saw, front, page, love, song]
# 3                               [blowing, mind, yet]
# 4                            [gone, dunder, mifflin]
#
#                                            com_lemma  \
# 0  [everyone, know, brand, paper, one, know, welf...
# 1                              [paper, cut, balance]
# 2           [oh, shit, saw, front, page, love, song]
# 3                               [blowing, mind, yet]
# 4                            [gone, dunder, mifflin]
#
#                                             com_stem  \
# 0  [everyon, know, brand, paper, one, know, welfa...
# 1                               [paper, cut, balanc]
# 2           [oh, shit, saw, front, page, love, song]
# 3                                  [blow, mind, yet]
# 4                            [gone, dunder, mifflin]
#
#                                          com_tok_str  \
# 0  everyon, know, brand, paper, one, know, welfar...
# 1                                 paper, cut, balanc
# 2             oh, shit, saw, front, page, love, song
# 3                                    blow, mind, yet
# 4                              gone, dunder, mifflin
#
#                                             com_full
# 0  everyone knows brand papers one knows welfare ...
# 1                                  paper cut balance
# 2                   oh shit saw front page love song
# 3                                   blowing mind yet
# 4                                gone dunder mifflin

# %%
def drop_cols_after_nlp(comments):
    comments = comments.drop(columns = ['comment', 'com_token', 'com_remv', 'com_lemma', 'com_stem', 'com_tok_str'], axis = 1)
    return comments
comments = drop_cols_after_nlp(comments)
comments.head()
# Out:
#    label                                           com_full
# 0   -1.0  everyone knows brand papers one knows welfare ...
# 1    0.0                                  paper cut balance
# 2    1.0                   oh shit saw front page love song
# 3    1.0                                   blowing mind yet
# 4    0.0                                gone dunder mifflin

# %%
comments.rename(columns = {'com_full': 'comment'}, inplace=True)
comments.head()
# Out:
#    label                                            comment
# 0   -1.0  everyone knows brand papers one knows welfare ...
# 1    0.0                                  paper cut balance
# 2    1.0                   oh shit saw front page love song
# 3    1.0                                   blowing mind yet
# 4    0.0                                gone dunder mifflin

# %%
def remove_missing_vals(comments):
    comments['comment'] = comments['comment'].str.strip()
    comments = comments[comments.comment != 'nan'] # remove nan values from data
    comments = comments[comments.comment != '']

remove_missing_vals(comments)

# %%
comments.head()
# Out:
#    label                                            comment
# 0   -1.0  everyone knows brand papers one knows welfare ...
# 1    0.0                                  paper cut balance
# 2    1.0                   oh shit saw front page love song
# 3    1.0                                   blowing mind yet
# 4    0.0                                gone dunder mifflin

# %%
comments['label'].isna().sum()
# Out:
# 2355

# %%
comments = comments[comments['label'].notna()]
comments['label'].isna().sum()
# Out:
# 0

# %%
len(comments)
# Out:
# 14830

# %%
x= comments['comment']
y = comments.label

# %%
x
# Out:
# 0        everyone knows brand papers one knows welfare ...
# 1                                        paper cut balance
# 2                         oh shit saw front page love song
# 3                                         blowing mind yet
# 4                                      gone dunder mifflin
#                                ...
# 17180                                      cop con twitter
# 17181          buenas noches genteeee twitter los quierooo
# 17182    twitter tiene la mala costumbre de ponerce bno...
# 17183    oi flaviasansi muito bem vinda ao meu twitter ...
# 17184    eles arrastaram os barcos para praia deixaram ...
# Name: comment, Length: 14830, dtype: object

# %%
y
# Out:
# 0       -1.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 17180    0.0
# 17181    0.0
# 17182    0.0
# 17183    0.0
# 17184    0.0
# Name: label, Length: 14830, dtype: float64

# %%
# Set seed for reproducibility
import random; random.seed(5)

# Import all we need from sklearn
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn import metrics

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=53, test_size=0.25)

# %% [markdown]
# **Vectorize the tweets**

# %%
count_vectorizer = CountVectorizer(stop_words='english',
                                   min_df=0.05, max_df=0.9)

# Create count train and test variables
count_train = count_vectorizer.fit_transform(X_train)
count_test = count_vectorizer.transform(X_test)

# Initialize tfidf vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english',
                                   min_df=0.05, max_df=0.9)

# Create tfidf train and test variables
tfidf_train = tfidf_vectorizer.fit_transform(X_train)
tfidf_test = tfidf_vectorizer.transform(X_test)

# %%
import random; random.seed(5)

# Import all we need from sklearn
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn import metrics

# %% [markdown]
# **Multinomial Naive-Bayes Model**

# %%
tfidf_nb = MultinomialNB()
tfidf_nb.fit(tfidf_train,y_train)
# Run predict on your TF-IDF test data to get your predictions
tfidf_nb_pred = tfidf_nb.predict(tfidf_test)

# Calculate the accuracy of your predictions
tfidf_nb_score = metrics.accuracy_score(y_test,tfidf_nb_pred)

# Create a MulitnomialNB model
count_nb = MultinomialNB()
count_nb.fit(count_train,y_train)

# Run predict on your count test data to get your predictions
count_nb_pred = count_nb.predict(count_test)

# Calculate the accuracy of your predictions
count_nb_score = metrics.accuracy_score(count_nb_pred,y_test)

print('NaiveBayes Tfidf Score: ', tfidf_nb_score)
print('NaiveBayes Count Score: ', count_nb_score)
# Out:
# NaiveBayes Tfidf Score:  0.7909924487594391
# NaiveBayes Count Score:  0.7831715210355987

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(tfidf_train,y_train)
accuracy_lr = lr_model.score(tfidf_test,y_test)
print("Logistic Regression accuracy is (for Tfidf) :",accuracy_lr)
# Out:
# Logistic Regression accuracy is (for Tfidf) : 0.7880258899676376

# %%
lr_model = LogisticRegression()
lr_model.fit(count_train,y_train)
accuracy_lr = lr_model.score(count_test,y_test)
print("Logistic Regression accuracy is (for Count) :",accuracy_lr)
# Out:
# Logistic Regression accuracy is (for Count) : 0.7877562028047465

# %% [markdown]
# **Support Vector Machine**

# %%
count_svc = svm.SVC(kernel='linear', C=1)

count_svc.fit(count_train,y_train)
# Run predict on your count test data to get your predictions
count_svc_pred = count_svc.predict(count_test)

# Calculate your accuracy using the metrics module
count_svc_score = metrics.accuracy_score(y_test,count_svc_pred)

print("LinearSVC Score (for Count):   %0.3f" % tfidf_svc_score)
# Out:
# LinearSVC Score (for Count):   0.792

# %% [markdown]
# **Desicion Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(tfidf_train,y_train)
accuracy_dt = dt_model.score(tfidf_test,y_test)
print("Decision Tree accuracy is (for Tfidf):",accuracy_dt)
# Out:
# Decision Tree accuracy is (for Tfidf): 0.7982740021574973

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(count_train,y_train)
accuracy_dt = dt_model.score(count_test,y_test)
print("Decision Tree accuracy is (for Count):",accuracy_dt)
# Out:
# Decision Tree accuracy is (for Count): 0.7977346278317152

# %% [markdown]
# **Predicting Sentiment For any given video**

# %% [markdown]
# **Reading Data**

# %%
prediction_comments = pd.read_csv('/content/Comments.csv', delimiter=",", encoding='utf-8', engine='python')
prediction_comments = prediction_comments.iloc[:,:1]
prediction_comments.columns=['comment']
prediction_comments.head()
# Out:
#                                              comment
# 0  What do YOU think to the current state of Fold...
# 1  Well, finally someone who can compete with Sam...
# 2  I wanna see them attempt something like the Z-...
# 3  4:57 "And then actually coming with the charge...
# 4  Personally, for me this was one of, if not the...

# %%
len(prediction_comments['comment'])
# Out:
# 1001

# %%
convert_to_string(prediction_comments)
cleanerFn(prediction_comments)
prediction_comments = nlpFunction(prediction_comments)
prediction_comments = drop_cols_after_nlp(prediction_comments)
prediction_comments.rename(columns = {'com_full': 'comment'}, inplace=True)
remove_missing_vals(prediction_comments)
prediction_comments.head()
# Out:
#                                              comment
# 0  think current state foldable phones check tesl...
# 1  well finally someone compete samsung market co...
# 2  wanna see attempt something like z flip someth...
# 3  actually coming charger respect xiaomi getting...
# 4  personally one best video ever made simple alw...

# %%
tfidf_pred = tfidf_vectorizer.transform(prediction_comments['comment'])
tfidf_svc_pred = tfidf_svc.predict(tfidf_pred)

# %%
neutral = (tfidf_svc_pred == 0.0).sum()
positive = (tfidf_svc_pred == 1.0).sum()
negative = (tfidf_svc_pred < 0).sum()

# %%
print(neutral, positive, negative)

# %%
print("Good video" if positive > negative else "Bad video")
# Out:
# Good video
